# %% [markdown]
# # It can help you devide your datasets into Folds (etc. 4-folds)
#
# And also can create train,validation,test sets

# %%
import os
import random

# %%
DATA_DIR='/home/piai/Desktop/AFAD' # the location where your image dataset is
original_folds_dir='/home/piai/Desktop/folds/original_txt_files' # the location where your original folds data is
out_files_dir='/home/piai/Desktop/folds/train_val_txt_files_per_fold' # your output location

# %%
# Age and Gender Bins your model would predict  
age_list=['(18, 19)','(20, 24)','(25, 29)','(30, 34)','(35, 39)']
gender_list=['m','f']

# %%
# this source code is gonna create 4 folds

for cur_test_fold_ind in range(4):
    cur_fold_out_foldername='test_fold_is_{0}'.format(cur_test_fold_ind)
    cur_fold_out_foldername=os.path.join(out_files_dir,cur_fold_out_foldername)
    
    if not os.path.exists(cur_fold_out_foldername):
        os.mkdir(cur_fold_out_foldername)
    
    
    #test files
    cur_test_fold_filename='fold_{0}_data.txt'.format(cur_test_fold_ind)
    cur_test_fold_filename=os.path.join(original_folds_dir,cur_test_fold_filename)
    
    with open(cur_test_fold_filename) as f:
        def_lines=f.readlines()
    
    def_lines.pop(0)
    
    full_test_list=[]
    for idx,def_line in enumerate(def_lines):
        def_dic={}
        
        image_name= def_line.split('\t')[0]

        image_age=def_line.split('\t')[2][:-1] 
        
        image_gender=def_line.split('\t')[1]
        
        
        def_dic['image_name']=image_name
        def_dic['image_age']=image_age
        def_dic['image_gender']=image_gender
        
        if idx % 500 == 0 :
            print(def_dic)
        
        full_test_list.append(def_dic)
    
    images_num=len(full_test_list)
    indices=random.sample(set(range(0,images_num)), images_num)

    
    #creating text.txt file
    age_test_txt_filename=os.path.join(cur_fold_out_foldername,'age_test.txt')
    gender_test_txt_filename=os.path.join(cur_fold_out_foldername,'gender_test.txt')

    for f in [age_test_txt_filename,gender_test_txt_filename]:
        if os.path.exists(f):
            os.remove(f)
        
    age_test_txt_file=open(age_test_txt_filename,'w+')
    gender_test_txt_file=open(gender_test_txt_filename,'w+')
    
    
    for ind in indices:
        image_name=full_test_list[ind]['image_name']
        image_age=full_test_list[ind]['image_age']
        image_gender=full_test_list[ind]['image_gender']
        
        if image_age in age_list:
            image_age_index=age_list.index(image_age)  
            s='{0} {1}\n'.format(image_name,image_age_index)
            age_test_txt_file.write(s)

        if image_gender in gender_list:
            image_gender_index=gender_list.index(image_gender)
            s='{0} {1}\n'.format(image_name,image_gender_index)
            gender_test_txt_file.write(s)
        

    for f in [age_test_txt_file,gender_test_txt_file]:
        f.close()
        
    
    
    full_train_list=[]
    train_folds_indices=list(set(range(4)) - set([cur_test_fold_ind]))
    
    for train_fold_ind in train_folds_indices:
        
        #train files
        cur_train_fold_filename='fold_{0}_data.txt'.format(train_fold_ind)
        cur_train_fold_filename=os.path.join(original_folds_dir,cur_train_fold_filename)

        with open(cur_train_fold_filename) as f:
            def_lines=f.readlines()

        def_lines.pop(0)

        for def_line in def_lines:
            def_dic={}
        
            image_name= def_line.split('\t')[0]

            image_age=def_line.split('\t')[2][:-1] 
        
            image_gender=def_line.split('\t')[1]
        
        
            def_dic['image_name']=image_name
            def_dic['image_age']=image_age
            def_dic['image_gender']=image_gender

            full_train_list.append(def_dic) 
    
    images_num=len(full_train_list)
    print(images_num)
    print(len(full_test_list))
    indices=random.sample(set(range(0,images_num)), images_num)
    
    val_indices=indices[:images_num//10]
    train_indices=indices[(images_num//10) + 1:]
    train_subset_indices=indices[(images_num//10) + 1: 2* (images_num//10)]
    #train files
    
    cases=['val','train','train_subset']
    
    for case,indices in zip(cases,[val_indices,train_indices,train_subset_indices]):
       
        age_txt_filename=os.path.join(cur_fold_out_foldername,'age_{0}.txt'.format(case))
        gender_txt_filename=os.path.join(cur_fold_out_foldername,'gender_{0}.txt'.format(case))
   
        for f in [age_txt_filename,gender_txt_filename]:
            if os.path.exists(f):
                os.remove(f)

        age_txt_file=open(age_txt_filename,'w+')
        gender_txt_file=open(gender_txt_filename,'w+')
        
        for ind in indices:
            image_name=full_train_list[ind]['image_name']
            image_age=full_train_list[ind]['image_age']
            image_gender=full_train_list[ind]['image_gender']
            
            if image_age in age_list:
                image_age_index=age_list.index(image_age)  
                s='{0} {1}\n'.format(image_name,image_age_index)
                age_txt_file.write(s)

            if image_gender in gender_list:
                image_gender_index=gender_list.index(image_gender)
                s='{0} {1}\n'.format(image_name,image_gender_index)
                gender_txt_file.write(s)

        for f in [age_txt_file,gender_txt_file]:
            f.close()
# Out:
# {'image_name': '156053-0.jpg', 'image_age': '(25, 29)', 'image_gender': 'm'}
# {'image_name': '17993-0.jpg', 'image_age': '(25, 29)', 'image_gender': 'm'}
# {'image_name': '196031-0.jpg', 'image_age': '(20, 24)', 'image_gender': 'f'}
# {'image_name': '248630-0.jpg', 'image_age': '(20, 24)', 'image_gender': 'f'}
# {'image_name': '25941-0.jpg', 'image_age': '(20, 24)', 'image_gender': 'f'}
# {'image_name': '37821-1.jpg', 'image_age': '(20, 24)', 'image_gender': 'f'}
# {'image_name': '190508-1.jpg', 'image_age': '(20, 24)', 'image_gender': 'm'}
# {'image_name': '420800-0.jpg', 'image_age': '(35, 39)', 'image_gender': 'm'}
# {'image_name': '45440-0.jpg', 'image_age': '(20, 24)', 'image_gender': 'f'}
# {'image_name': '262230-0.jpg', 'image_age': '(20, 24)', 'image_gender': 'm'}
# {'image_name': '102562-0.jpg', 'image_age': '(20, 24)', 'image_gender': 'f'}
# {'image_name': '252421-0.jpg', 'image_age': '(18, 19)', 'image_gender': 'f'}
# {'image_name': '409346-0.jpg', 'image_age': '(35, 39)', 'image_gender': 'm'}
# {'image_name': '227780-0.jpg', 'image_age': '(20, 24)', 'image_gender': 'f'}
# {'image_name': '23462-0.jpg', 'image_age': '(20, 24)', 'image_gender': 'f'}
# {'image_name': '137464-0.jpg', 'image_age': '(25, 29)', 'image_gender': 'm'}
# {'image_name': '168247-0.jpg', 'image_age': '(25, 29)', 'image_gender': 'f'}
# {'image_name': '38539-0.jpg', 'image_age': '(18, 19)', 'image_gender': 'm'}
# {'image_name': '126221-0.jpg', 'image_age': '(30, 34)', 'image_gender': 'm'}
# {'image_name': '228236-0.jpg', 'image_age': '(20, 24)', 'image_gender': 'm'}
# {'image_name': '123661-0.jpg', 'image_age': '(35, 39)', 'image_gender': 'm'}
# {'image_name': '306602-0.jpg', 'image_age': '(35, 39)', 'image_gender': 'f'}
# {'image_name': '250197-0.jpg', 'image_age': '(20, 24)', 'image_gender': 'm'}
# {'image_name': '96107-0.jpg', 'image_age': '(20, 24)', 'image_gender': 'f'}
# {'image_name': '8208-0.jpg', 'image_age': '(30, 34)', 'image_gender': 'f'}
# {'image_name': '205415-0.jpg', 'image_age': '(20, 24)', 'image_gender': 'm'}
# {'image_name': '168067-0.jpg', 'image_age': '(25, 29)', 'image_gender': 'f'}
# {'image_name': '272861-0.jpg', 'image_age': '(18, 19)', 'image_gender': 'm'}
# {'image_name': '269608-0.jpg', 'image_age': '(18, 19)', 'image_gender': 'm'}
# {'image_name': '175823-0.jpg', 'image_age': '(20, 24)', 'image_gender': 'm'}
# 44508
# 14836
# {'image_name': '278321-1.jpg', 'image_age': '(20, 24)', 'image_gender': 'f'}
# {'image_name': '582554-0.jpg', 'image_age': '(35, 39)', 'image_gender': 'm'}
# {'image_name': '46392-0.jpg', 'image_age': '(20, 24)', 'image_gender': 'f'}
# {'image_name': '151101-1.jpg', 'image_age': '(25, 29)', 'image_gender': 'm'}
# {'image_name': '144424-0.jpg', 'image_age': '(25, 29)', 'image_gender': 'm'}
# {'image_name': '177883-0.jpg', 'image_age': '(20, 24)', 'image_gender': 'f'}
# {'image_name': '470883-0.jpg', 'image_age': '(35, 39)', 'image_gender': 'm'}
# {'image_name': '5852-0.jpg', 'image_age': '(25, 29)', 'image_gender': 'm'}
# {'image_name': '37579-0.jpg', 'image_age': '(18, 19)', 'image_gender': 'm'}
# {'image_name': '23346-0.jpg', 'image_age': '(20, 24)', 'image_gender': 'f'}
# {'image_name': '130568-0.jpg', 'image_age': '(30, 34)', 'image_gender': 'm'}
# {'image_name': '182900-0.jpg', 'image_age': '(20, 24)', 'image_gender': 'm'}
# {'image_name': '446151-0.jpg', 'image_age': '(25, 29)', 'image_gender': 'm'}
# {'image_name': '238367-0.jpg', 'image_age': '(20, 24)', 'image_gender': 'm'}
# {'image_name': '311831-0.jpg', 'image_age': '(30, 34)', 'image_gender': 'f'}
# {'image_name': '22744-0.jpg', 'image_age': '(20, 24)', 'image_gender': 'm'}
# {'image_name': '187624-0.jpg', 'image_age': '(20, 24)', 'image_gender': 'm'}
# {'image_name': '104033-0.jpg', 'image_age': '(20, 24)', 'image_gender': 'f'}
# {'image_name': '218313-0.jpg', 'image_age': '(20, 24)', 'image_gender': 'f'}
# {'image_name': '70184-0.jpg', 'image_age': '(25, 29)', 'image_gender': 'm'}
# {'image_name': '476063-0.jpg', 'image_age': '(35, 39)', 'image_gender': 'm'}
# {'image_name': '247414-0.jpg', 'image_age': '(20, 24)', 'image_gender': 'f'}
# {'image_name': '210085-0.jpg', 'image_age': '(20, 24)', 'image_gender': 'f'}
# {'image_name': '449337-0.jpg', 'image_age': '(25, 29)', 'image_gender': 'm'}
# {'image_name': '160469-0.jpg', 'image_age': '(25, 29)', 'image_gender': 'f'}
# {'image_name': '31599-0.jpg', 'image_age': '(20, 24)', 'image_gender': 'm'}
# {'image_name': '182419-3.jpg', 'image_age': '(20, 24)', 'image_gender': 'm'}
# {'image_name': '176649-0.jpg', 'image_age': '(25, 29)', 'image_gender': 'f'}
# {'image_name': '213501-0.jpg', 'image_age': '(20, 24)', 'image_gender': 'f'}
# {'image_name': '316417-0.jpg', 'image_age': '(25, 29)', 'image_gender': 'm'}
# 44508
# 14836
# {'image_name': '397424-0.jpg', 'image_age': '(35, 39)', 'image_gender': 'f'}
# {'image_name': '201883-0.jpg', 'image_age': '(20, 24)', 'image_gender': 'f'}
# {'image_name': '219279-2.jpg', 'image_age': '(20, 24)', 'image_gender': 'f'}
# {'image_name': '105311-1.jpg', 'image_age': '(20, 24)', 'image_gender': 'm'}
# {'image_name': '286850-0.jpg', 'image_age': '(18, 19)', 'image_gender': 'f'}
# {'image_name': '281232-0.jpg', 'image_age': '(18, 19)', 'image_gender': 'm'}
# {'image_name': '14435-1.jpg', 'image_age': '(20, 24)', 'image_gender': 'm'}
# {'image_name': '258978-0.jpg', 'image_age': '(18, 19)', 'image_gender': 'm'}
# {'image_name': '420113-0.jpg', 'image_age': '(35, 39)', 'image_gender': 'm'}
# {'image_name': '247175-0.jpg', 'image_age': '(20, 24)', 'image_gender': 'm'}
# {'image_name': '192032-0.jpg', 'image_age': '(20, 24)', 'image_gender': 'm'}
# {'image_name': '235448-0.jpg', 'image_age': '(18, 19)', 'image_gender': 'f'}
# {'image_name': '123832-0.jpg', 'image_age': '(35, 39)', 'image_gender': 'm'}
# {'image_name': '67124-0.jpg', 'image_age': '(30, 34)', 'image_gender': 'f'}
# {'image_name': '127288-0.jpg', 'image_age': '(30, 34)', 'image_gender': 'm'}
# {'image_name': '419687-0.jpg', 'image_age': '(30, 34)', 'image_gender': 'm'}
# {'image_name': '484121-0.jpg', 'image_age': '(35, 39)', 'image_gender': 'm'}
# {'image_name': '204835-0.jpg', 'image_age': '(18, 19)', 'image_gender': 'm'}
# {'image_name': '190939-0.jpg', 'image_age': '(20, 24)', 'image_gender': 'f'}
# {'image_name': '112365-0.jpg', 'image_age': '(18, 19)', 'image_gender': 'f'}
# {'image_name': '267404-0.jpg', 'image_age': '(20, 24)', 'image_gender': 'f'}
# {'image_name': '134363-0.jpg', 'image_age': '(25, 29)', 'image_gender': 'm'}
# {'image_name': '212734-1.jpg', 'image_age': '(20, 24)', 'image_gender': 'm'}
# {'image_name': '50977-0.jpg', 'image_age': '(18, 19)', 'image_gender': 'f'}
# {'image_name': '224026-0.jpg', 'image_age': '(20, 24)', 'image_gender': 'm'}
# {'image_name': '265197-0.jpg', 'image_age': '(20, 24)', 'image_gender': 'm'}
# {'image_name': '195605-0.jpg', 'image_age': '(20, 24)', 'image_gender': 'm'}
# {'image_name': '41679-0.jpg', 'image_age': '(20, 24)', 'image_gender': 'm'}
# {'image_name': '157918-0.jpg', 'image_age': '(25, 29)', 'image_gender': 'm'}
# {'image_name': '445090-0.jpg', 'image_age': '(30, 34)', 'image_gender': 'f'}
# 44508
# 14836
# {'image_name': '307577-0.jpg', 'image_age': '(35, 39)', 'image_gender': 'm'}
# {'image_name': '134687-0.jpg', 'image_age': '(30, 34)', 'image_gender': 'm'}
# {'image_name': '221344-0.jpg', 'image_age': '(18, 19)', 'image_gender': 'm'}
# {'image_name': '474892-0.jpg', 'image_age': '(35, 39)', 'image_gender': 'f'}
# {'image_name': '311665-0.jpg', 'image_age': '(30, 34)', 'image_gender': 'f'}
# {'image_name': '417301-0.jpg', 'image_age': '(35, 39)', 'image_gender': 'm'}
# {'image_name': '70858-0.jpg', 'image_age': '(25, 29)', 'image_gender': 'm'}
# {'image_name': '173674-0.jpg', 'image_age': '(20, 24)', 'image_gender': 'm'}
# {'image_name': '192065-0.jpg', 'image_age': '(20, 24)', 'image_gender': 'f'}
# {'image_name': '208658-1.jpg', 'image_age': '(20, 24)', 'image_gender': 'f'}
# {'image_name': '126999-0.jpg', 'image_age': '(35, 39)', 'image_gender': 'm'}
# {'image_name': '481932-0.jpg', 'image_age': '(35, 39)', 'image_gender': 'f'}
# {'image_name': '5762-1.jpg', 'image_age': '(30, 34)', 'image_gender': 'm'}
# {'image_name': '256345-0.jpg', 'image_age': '(20, 24)', 'image_gender': 'f'}
# {'image_name': '254136-0.jpg', 'image_age': '(20, 24)', 'image_gender': 'm'}
# {'image_name': '314124-1.jpg', 'image_age': '(25, 29)', 'image_gender': 'm'}
# {'image_name': '6753-0.jpg', 'image_age': '(30, 34)', 'image_gender': 'm'}
# {'image_name': '316457-0.jpg', 'image_age': '(25, 29)', 'image_gender': 'm'}
# {'image_name': '273744-0.jpg', 'image_age': '(20, 24)', 'image_gender': 'f'}
# {'image_name': '310061-1.jpg', 'image_age': '(30, 34)', 'image_gender': 'm'}
# {'image_name': '193212-1.jpg', 'image_age': '(20, 24)', 'image_gender': 'm'}
# {'image_name': '410448-0.jpg', 'image_age': '(35, 39)', 'image_gender': 'm'}
# {'image_name': '213243-0.jpg', 'image_age': '(25, 29)', 'image_gender': 'm'}
# {'image_name': '482337-0.jpg', 'image_age': '(35, 39)', 'image_gender': 'm'}
# {'image_name': '278390-0.jpg', 'image_age': '(18, 19)', 'image_gender': 'f'}
# {'image_name': '54167-0.jpg', 'image_age': '(18, 19)', 'image_gender': 'f'}
# {'image_name': '139127-1.jpg', 'image_age': '(25, 29)', 'image_gender': 'm'}
# {'image_name': '134132-0.jpg', 'image_age': '(25, 29)', 'image_gender': 'm'}
# {'image_name': '9867-0.jpg', 'image_age': '(30, 34)', 'image_gender': 'm'}
# {'image_name': '432419-0.jpg', 'image_age': '(30, 34)', 'image_gender': 'f'}
# 44508
# 14836
